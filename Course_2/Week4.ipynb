# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  '_classic_test']

# %%
plt.style.use('seaborn-colorblind')

# %% [markdown]
# # Plotting dataframes

# %%
np.random.seed?

# %%
np.random.seed(123)

# %%
df=pd.DataFrame({'A':np.random.randn(365).cumsum(0),
                'B':np.random.randn(365).cumsum(0)+20,
                'C':np.random.randn(365).cumsum(0)-20},
               index=pd.date_range('1/1/2017',periods=365))

# %%
df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.725890  20.232037 -19.806906
# 2017-01-02 -1.114652  21.732960 -19.367436
# 2017-01-03  0.194699  22.224917 -17.985262
# 2017-01-04  0.890578  22.035535 -18.117128
# 2017-01-05  1.210887  22.095478 -19.511836

# %%
df
# Out:
#                     A          B          C
# 2017-01-01  -1.725890  20.232037 -19.806906
# 2017-01-02  -1.114652  21.732960 -19.367436
# 2017-01-03   0.194699  22.224917 -17.985262
# 2017-01-04   0.890578  22.035535 -18.117128
# 2017-01-05   1.210887  22.095478 -19.511836
# 2017-01-06   0.565961  22.422818 -20.265845
# 2017-01-07   2.141611  22.043852 -19.725452
# 2017-01-08   2.894887  22.726089 -19.809982
# 2017-01-09   3.179357  24.351177 -19.530691
# 2017-01-10   3.384217  23.988028 -19.883771
# 2017-01-11   3.495844  25.195559 -18.013962
# 2017-01-12   3.948061  26.071885 -16.285974
# 2017-01-13   3.334734  26.609130 -17.217570
# 2017-01-14   4.859984  26.721056 -16.308539
# 2017-01-15   5.012323  27.058839 -16.004476
# 2017-01-16   5.612378  26.841446 -15.990917
# 2017-01-17   5.178811  28.678315 -16.850605
# 2017-01-18   5.553729  27.959912 -15.229074
# 2017-01-19   3.271977  29.094856 -14.063816
# 2017-01-20   2.153678  30.644578 -15.520916
# 2017-01-21   2.122265  30.321444 -14.137425
# 2017-01-22   0.799791  31.487291 -14.175803
# 2017-01-23   3.239206  31.631272 -14.773593
# 2017-01-24   1.571124  31.693632 -15.750171
# 2017-01-25   1.917025  31.619068 -14.805351
# 2017-01-26   3.572798  30.005337 -14.405455
# 2017-01-27   4.054085  30.553261 -15.279602
# 2017-01-28   3.743858  31.996813 -16.090699
# 2017-01-29   3.191714  31.292092 -16.478223
# 2017-01-30   3.864969  32.139431 -16.990729
# ...               ...        ...        ...
# 2017-12-02  13.715970  -1.554134  16.189568
# 2017-12-03  12.829966  -1.984794  17.019116
# 2017-12-04  12.703579  -2.131210  16.257587
# 2017-12-05  13.445952  -0.971034  16.635292
# 2017-12-06  14.071382  -1.612546  15.447858
# 2017-12-07  16.150921  -1.912778  15.925591
# 2017-12-08  15.799514  -2.545039  17.009598
# 2017-12-09  17.085516  -2.749356  17.019369
# 2017-12-10  16.831215  -2.535660  18.568052
# 2017-12-11  16.130315  -1.501782  18.428144
# 2017-12-12  14.507362  -3.626357  18.839512
# 2017-12-13  14.670032  -3.070868  17.914045
# 2017-12-14  14.148727  -3.962458  18.352476
# 2017-12-15  14.996244  -3.369388  17.784337
# 2017-12-16  14.467843  -2.129753  17.063945
# 2017-12-17  13.991242  -1.134158  18.644049
# 2017-12-18  14.345897  -0.976199  17.373828
# 2017-12-19  16.067113  -0.141700  17.259060
# 2017-12-20  14.978463  -1.085084  17.971850
# 2017-12-21  15.996076  -1.152914  18.205921
# 2017-12-22  16.870181   0.366557  16.358594
# 2017-12-23  16.649235  -0.422699  16.962503
# 2017-12-24  17.324652  -0.225430  15.583504
# 2017-12-25  17.040375  -0.594605  15.140252
# 2017-12-26  19.411764  -0.789714  14.896009
# 2017-12-27  19.299668  -0.383642  11.975980
# 2017-12-28  19.380082  -0.653161  11.870080
# 2017-12-29  19.054291  -0.656570  12.535957
# 2017-12-30  17.360837  -1.161154  12.365873
# 2017-12-31  17.097683  -2.986182  12.550802
#
# [365 rows x 3 columns]

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot('A','B',kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.scatter('A','C',c='B',s=df['B'],colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\INSTALL\Anaconda\lib\site-packages\matplotlib\collections.py:836: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
ax = df.plot.scatter('A','C',c='B',s=df['B'],colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\INSTALL\Anaconda\lib\site-packages\matplotlib\collections.py:836: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
np.random.seed(1234)
v1=pd.Series(np.random.normal(0,10,1000),name='V1')
v2=pd.Series(2*v1+np.random.normal(60,15,1000),name='V2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50,150,5),label='V1')
plt.hist(v2, alpha=0.7, bins=np.arange(-50,150,5),label='V2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist([v1,v2],histtype='barstacked',normed=True)
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color':'Teal'},kde_kws={'color':'Navy'})
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(v1,v2,alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
grid= sns.jointplot(v1,v2,alpha=0.4)
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(v1,v2,kind='hex')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')
sns.jointplot(v1,v2,kind='kde',space=0)
# Out:
# <img src="data:image/png;base64,..." width="600">
