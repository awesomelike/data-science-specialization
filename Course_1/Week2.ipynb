# %%
import pandas as pd

# %%
pd.Series
# Out:
# pandas.core.series.Series

# %%
pd.Series?

# %%
animals = ['Tigers','Bears','Moose']

# %%
pd.Series(animals)
# Out:
# 0    Tigers
# 1     Bears
# 2     Moose
# dtype: object

# %%
numbers=[1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
numbers=[1,2,None]

# %%
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
animals = ['Tiger','Moose','Bear',None]

# %%
pd.Series(animals)
# Out:
# 0    Tiger
# 1    Moose
# 2     Bear
# 3     None
# dtype: object

# %%
import numpy as np

# %%
np.nan ==None
# Out:
# False

# %%
np.nan==np.nan
# Out:
# False

# %%
None==None
# Out:
# True

# %%
np.isnan(np.nan)
# Out:
# True

# %%
np.isnan(np.nan)
# Out:
# True

# %%
np.isnan(NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5350f6c47d8a> in <module>()
# ----> 1 np.isnan(NaN)
#
# NameError: name 'NaN' is not defined

# %% [markdown]
# # Querying a Series

# %%
students = {'u1710008':'Abdullaev Azamat',
           'u1710047':'Inadullaev Makhmud',
           'u1710095':'Yuldashev Jasur'}

# %%
pd.Series(students)
# Out:
# u1710008      Abdullaev Azamat
# u1710047    Inadullaev Makhmud
# u1710095       Yuldashev Jasur
# dtype: object

# %%
studentSeries = pd.Series(students)

# %%
studentSeries['u1710008']
# Out:
# 'Abdullaev Azamat'

# %%
studentSeries['u1710047']
# Out:
# 'Inadullaev Makhmud'

# %%
studentSeries['u1710095']
# Out:
# 'Yuldashev Jasur'

# %%
studentSeries.iloc[2]
# Out:
# 'Yuldashev Jasur'

# %%
studentSeries.iloc[0]
# Out:
# 'Abdullaev Azamat'

# %%
studentSeries[0]
# Out:
# 'Abdullaev Azamat'

# %%
s=pd.Series([1,24,51,73,-53])
total=0
for item in s:
    total+=item
print(total)
# Out:
# 96

# %%
import numpy as np

# %%
s=pd.Series(np.random.randint(0,1000,10000))
s.head()
# Out:
# 0    711
# 1     19
# 2    938
# 3    792
# 4    157
# dtype: int32

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 10
summary=0
for item in s:
    summary+=item
# Out:
# 1.35 ms ± 522 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 100
summary=0
for item in s:
    summary+=item
# Out:
# 975 µs ± 88.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# 157 µs ± 24.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s+=2

# %%
s
# Out:
# 0       713
# 1        21
# 2       940
# 3       794
# 4       159
# 5       465
# 6       408
# 7       408
# 8       100
# 9       702
# 10      968
# 11      358
# 12      668
# 13      340
# 14      838
# 15      697
# 16      463
# 17        7
# 18      870
# 19      934
# 20      980
# 21      788
# 22      626
# 23      428
# 24      179
# 25      822
# 26      633
# 27      262
# 28      462
# 29      937
#        ...
# 9970    155
# 9971    693
# 9972    347
# 9973    222
# 9974      9
# 9975    184
# 9976    108
# 9977    420
# 9978     34
# 9979    163
# 9980    310
# 9981    837
# 9982    351
# 9983    912
# 9984    353
# 9985    513
# 9986    605
# 9987    351
# 9988    985
# 9989    271
# 9990    138
# 9991    515
# 9992     85
# 9993    692
# 9994    222
# 9995    144
# 9996    493
# 9997    226
# 9998    647
# 9999    790
# Length: 10000, dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label] = value+2
# Out:
# 614 ms ± 24.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
s=pd.Series(np.random.randint(0,1000,10000))
s+=2
# Out:
# 387 µs ± 76.4 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # DataFrame Data Structure

# %%
p1=pd.Series({'Name':'Chris',
             'Item':'Yogurt',
             'Cost':23.12})

# %%
p2=pd.Series({'Name':'Mike',
             'Item':'Dog food',
             'Cost':12.33})

# %%
df = pd.DataFrame([p1,p2],index=['Makro','Korzinka'])

# %%
df.headad()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-c3355d5e8da5> in <module>()
# ----> 1 df.headad()
#
# D:\INSTALL\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'headad'

# %%
df.head()
# Out:
#            Cost      Item  Name
# Makro     12.33  Dog food  Mike
# Korzinka  12.33  Dog food  Mike

# %%
df = DataFrame([p1,p2],index=['Makro','Korzinka'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-3b71abe67eab> in <module>()
# ----> 1 df = DataFrame([p1,p2],index=['Makro','Korzinka'])
#
# NameError: name 'DataFrame' is not defined

# %%
df = pd.DataFrame([p1,p2],index=['Makro','Korzinka'])
df
# Out:
#            Cost      Item   Name
# Makro     23.12    Yogurt  Chris
# Korzinka  12.33  Dog food   Mike

# %%
df.loc['Makro']
# Out:
# Cost     23.12
# Item    Yogurt
# Name     Chris
# Name: Makro, dtype: object

# %%
type(df.loc['Makro'])
# Out:
# pandas.core.series.Series

# %%
df.T
# Out:
#        Makro  Korzinka
# Cost   23.12     12.33
# Item  Yogurt  Dog food
# Name   Chris      Mike

# %%
df.loc['Makro']['Cost']
# Out:
# 23.120000000000001

# %%
df.drop('Makro')
# Out:
#            Cost      Item  Name
# Korzinka  12.33  Dog food  Mike

# %%
df
# Out:
#            Cost      Item   Name
# Makro     23.12    Yogurt  Chris
# Korzinka  12.33  Dog food   Mike

# %%
copy_df=df.copy()

# %%
copy_df
# Out:
#            Cost      Item   Name
# Makro     23.12    Yogurt  Chris
# Korzinka  12.33  Dog food   Mike

# %%
import pandas as pd

# %%
df = pd.DataFrame

# %%
df = pd.read_csv('students_.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of             ID                        name  year department yearAlias email
# 0     U1410002      ABDURASUL ABDUGAFFOROV     4      SOCIE    Senior  none
# 1     U1410007          JAMSHIDJON ASKAROV     4      SOCIE    Senior  none
# 2     U1410026         BAKHTIYOR NORTAJIEV     4      SOCIE    Senior  none
# 3     U1410040            DILMUROD VAKILOV     4      SOCIE    Senior  none
# 4     U1410042            Aziza Yuldasheva     4      SOCIE    Senior  none
# 5     U1410048        ISLOMJON AKHMADJONOV     4      SOCIE    Senior  none
# 6     U1410053              ILDAR ERGASHEV     4      SOCIE    Senior  none
# 7     U1410054            DILMUROD ERKINOV     4      SOCIE    Senior  none
# 8     U1410065           KHAMDAMOV BEKHZOD     4      SOCIE    Senior  none
# 9     U1410077     SHAVKATJON MAMASHOKIROV     4      SOCIE    Senior  none
# 10    U1410081    NURSULTON MUKHAMMADALIEV     4      SOCIE    Senior  none
# ...

# %%
df = pd.read_csv('students_.csv',index_col=0, skiprows=1)

# %%
df.head
# Out:
# <bound method NDFrame.head of               ABDURASUL ABDUGAFFOROV  4  SOCIE    Senior  none
# U1410002
# U1410007          JAMSHIDJON ASKAROV  4  SOCIE    Senior  none
# U1410026         BAKHTIYOR NORTAJIEV  4  SOCIE    Senior  none
# U1410040            DILMUROD VAKILOV  4  SOCIE    Senior  none
# U1410042            Aziza Yuldasheva  4  SOCIE    Senior  none
# U1410048        ISLOMJON AKHMADJONOV  4  SOCIE    Senior  none
# U1410053              ILDAR ERGASHEV  4  SOCIE    Senior  none
# U1410054            DILMUROD ERKINOV  4  SOCIE    Senior  none
# U1410065           KHAMDAMOV BEKHZOD  4  SOCIE    Senior  none
# U1410077     SHAVKATJON MAMASHOKIROV  4  SOCIE    Senior  none
# U1410081    NURSULTON MUKHAMMADALIEV  4  SOCIE    Senior  none
# U1410126            VALISHER KODIROV  4  SOCIE    Senior  none
# U1410128            AZIZJON NIGMATOV  4  SOCIE    Senior  none
# U1510001             Daler Abdullaev  4  SOCIE    Senior  none
# ...

# %%
df.columns
# Out:
# Index(['ABDURASUL ABDUGAFFOROV', '4', 'SOCIE', 'Senior', 'none'], dtype='object')

# %% [markdown]
# # Querying a DataFrame

# %%
import numpy as np

# %%
x = np.array([-5,23,116,-35])

# %%
mask = (x<0)

# %%
mask
# Out:
# array([ True, False, False,  True], dtype=bool)

# %% [markdown]
# awesome, very useful

# %%
df = pd.read_csv('C:/Users/USER/Documents/google-play-store-apps/googleplaystore.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
df["Type"]
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
# 5        Free
# 6        Free
# 7        Free
# 8        Free
# 9        Free
# 10       Free
# 11       Free
# 12       Free
# 13       Free
# 14       Free
# 15       Free
# 16       Free
# 17       Free
# 18       Free
# 19       Free
# 20       Free
# 21       Free
# 22       Free
# 23       Free
# 24       Free
# 25       Free
# 26       Free
# 27       Free
# 28       Free
# 29       Free
#          ...
# 10811    Free
# 10812    Free
# 10813    Free
# 10814    Free
# 10815    Free
# 10816    Free
# 10817    Free
# 10818    Free
# 10819    Free
# 10820    Free
# 10821    Free
# 10822    Free
# 10823    Free
# 10824    Free
# 10825    Free
# 10826    Free
# 10827    Free
# 10828    Free
# 10829    Free
# 10830    Free
# 10831    Free
# 10832    Free
# 10833    Free
# 10834    Free
# 10835    Free
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# ...

# %%
df["App"]
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
# 5                               Paper flowers instructions
# 6                  Smoke Effect Photo Maker - Smoke Editor
# 7                                         Infinite Painter
# 8                                     Garden Coloring Book
# 9                            Kids Paint Free - Drawing Fun
# 10                                 Text on Photo - Fonteee
# 11                 Name Art Photo Editor - Focus n Filters
# 12                          Tattoo Name On My Photo Editor
# 13                                   Mandala Coloring Book
# 14         3D Color Pixel by Number - Sandbox Art Coloring
# 15                         Learn To Draw Kawaii Characters
# ...

# %%
df["Rating"] >=4.0
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
# 5         True
# 6        False
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15       False
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23       False
# 24        True
# 25        True
# 26        True
# 27        True
# 28       False
# 29        True
#          ...
# 10811    False
# 10812     True
# 10813    False
# 10814     True
# 10815     True
# 10816    False
# 10817     True
# 10818    False
# 10819    False
# 10820     True
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826     True
# 10827     True
# 10828    False
# 10829     True
# 10830    False
# 10831    False
# 10832    False
# 10833     True
# 10834     True
# 10835    False
# 10836     True
# 10837     True
# ...

# %%
only_highs = df.where(df["Rating"]>=4.0)

# %%
only_highs.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                                NaN             NaN     NaN
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     NaN   NaN          NaN   NaN   NaN            NaN
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                     Genres     Last Updated         Current Ver   Android Ver
# 0             Art & Design  January 7, 2018               1.0.0  4.0.3 and up
# ...

# %%
only_highs
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                                    NaN                  NaN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                                                    NaN                  NaN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
only_highs["Rating"].count()
# Out:
# 7369

# %%
df["Rating"].count()
# Out:
# 9367

# %%
only_highs = only_highs.dropna()

# %%
only_highs["Rating"].count()
# Out:
# 7363

# %%
only_highs
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# ...

# %% [markdown]
# # Indexing DataFrames

# %%
df["App"] = df.index

# %%
df = df.set_index("Rating")

# %%
df.head()
# Out:
#         App        Category Reviews  Size     Installs  Type Price  \
# Rating
# 4.1       0  ART_AND_DESIGN     159   19M      10,000+  Free     0
# 3.9       1  ART_AND_DESIGN     967   14M     500,000+  Free     0
# 4.7       2  ART_AND_DESIGN   87510  8.7M   5,000,000+  Free     0
# 4.5       3  ART_AND_DESIGN  215644   25M  50,000,000+  Free     0
# 4.3       4  ART_AND_DESIGN     967  2.8M     100,000+  Free     0
#
#        Content Rating                     Genres      Last Updated  \
# Rating
# 4.1          Everyone               Art & Design   January 7, 2018
# 3.9          Everyone  Art & Design;Pretend Play  January 15, 2018
# 4.7          Everyone               Art & Design    August 1, 2018
# 4.5              Teen               Art & Design      June 8, 2018
# 4.3          Everyone    Art & Design;Creativity     June 20, 2018
#
#                Current Ver   Android Ver
# Rating
# 4.1                  1.0.0  4.0.3 and up
# 3.9                  2.0.0  4.0.3 and up
# ...

# %%
newdf = pd.DataFrame({"month":[4,12,6,9],
                     "year": [2016,2018,2019,2015],
                     "sale":[34,51,90,52]})

# %%
newdf.set_index('month')
# Out:
#        sale  year
# month
# 4        34  2016
# 12       51  2018
# 6        90  2019
# 9        52  2015

# %%
newdf.set_index(['year','month'])
# Out:
#             sale
# year month
# 2016 4        34
# 2018 12       51
# 2019 6        90
# 2015 9        52

# %%
newdf
# Out:
#    month  sale  year
# 0      4    34  2016
# 1     12    51  2018
# 2      6    90  2019
# 3      9    52  2015

# %%
new_newdf
# Out:
#             sale
# month year
# 4     2016    34
# 12    2018    51
# 6     2019    90
# 9     2015    52

# %%
new_newdf = newdf.set_index(['year','month'])
